# %%
def select_from_list(lst, i_tuple):
    return [lst[i] for i in i_tuple]

select_from_list([1,2,4,6], (1,3,0))
# Out:
# [2, 6, 1]

# %%
lst = input('Please enter a list _ ')

index_numbers = input('Please enter index numbers _ ')

# %%
number = 526
outliers = {4:'IV', 9:'IX', 40:'XL', 90:'XC', 400:'CD', 900:'CM'}
symbols = {1:'I', 2:'II', 3:'III', 4:'IV', 5:'V', 6:'VI', 7:'VII', 
           8:'VIII', 9:'IX', 10:'X', 50:'L', 100:'C', 500:'D', 1000:'M'}
if number in outliers.keys():
    print(outliers[number])
else:
    layers = [symbols[10**i] * int(str(number)[::-1][i])for i in range(len(str(number)))]
print(layers)
# Out:
# ['IIIIII', 'XX', 'CCCCC']

# %%
number = 3999
symbols = {1:'I', 2:'II', 3:'III', 4:'IV', 5:'V', 6:'VI', 7:'VII', 
           8:'VIII', 9:'IX', 10:'X', 50:'L', 100:'C', 500:'D', 1000:'M',
           40:'XL', 90:'XC', 400:'CD', 900:'CM'}
r_number = str(number)[::-1]
layers = (10**i * int(r_number[i]) for i in range(len(r_number)))
numeral = []
for i, p in enumerate(layers):
    if p in symbols.keys():
        numeral.append(symbols[p])
    elif int(str(p)[0]) < 4:
        numeral.append(symbols[10 ** (len(str(p)) -1)] * int(r_number[i]))
    else:
        numeral.append(symbols[10 ** (len(str(p)) -1) * 5]+ symbols[10 ** (len(str(p)) -1)] * (int(r_number[i]) - 5))
numeral.reverse()
print(''.join(numeral))
# Out:
# MMMCMXCIX

# %%
for number in range(1, 4000):
    symbols = {1:'I', 2:'II', 3:'III', 4:'IV', 5:'V', 6:'VI', 7:'VII', 
           8:'VIII', 9:'IX', 10:'X', 50:'L', 100:'C', 500:'D', 1000:'M',
           40:'XL', 90:'XC', 400:'CD', 900:'CM'}
    r_number = str(number)[::-1]
    layers = (10**i * int(r_number[i]) for i in range(len(r_number)))
    numeral = []
    for i, p in enumerate(layers):
        if p in symbols.keys():
            numeral.append(symbols[p])
        elif int(str(p)[0]) < 4:
            numeral.append(symbols[10 ** (len(str(p)) -1)] * int(r_number[i]))
        else:
            numeral.append(symbols[10 ** (len(str(p)) -1) * 5]+ symbols[10 ** (len(str(p)) -1)] * (int(r_number[i]) - 5))
    numeral.reverse()
    print(''.join(numeral))
# Out:
# I
# II
# III
# IV
# V
# VI
# VII
# VIII
# IX
# X
# XI
# XII
# XIII
# XIV
# XV
# XVI
# XVII
# XVIII
# XIX
# XX
# XXI
# XXII
# XXIII
# XXIV
# XXV
# XXVI
# XXVII
# XXVIII
# XXIX
# XXX
# XXXI
# XXXII
# XXXIII
# XXXIV
# XXXV
# XXXVI
# XXXVII
# XXXVIII
# XXXIX
# XL
# XLI
# XLII
# XLIII
# XLIV
# XLV
# XLVI
# XLVII
# XLVIII
# XLIX
# L
# LI
# LII
# LIII
# LIV
# LV
# LVI
# LVII
# LVIII
# LIX
# LX
# LXI
# LXII
# LXIII
# LXIV
# LXV
# LXVI
# LXVII
# LXVIII
# LXIX
# LXX
# LXXI
# LXXII
# LXXIII
# LXXIV
# LXXV
# LXXVI
# LXXVII
# LXXVIII
# LXXIX
# LXXX
# LXXXI
# LXXXII
# LXXXIII
# LXXXIV
# LXXXV
# LXXXVI
# LXXXVII
# LXXXVIII
# LXXXIX
# XC
# XCI
# XCII
# XCIII
# XCIV
# XCV
# XCVI
# XCVII
# XCVIII
# XCIX
# C
# CI
# CII
# CIII
# CIV
# CV
# CVI
# CVII
# CVIII
# CIX
# CX
# CXI
# CXII
# CXIII
# CXIV
# CXV
# CXVI
# CXVII
# CXVIII
# CXIX
# CXX
# CXXI
# CXXII
# CXXIII
# CXXIV
# CXXV
# CXXVI
# CXXVII
# CXXVIII
# CXXIX
# CXXX
# CXXXI
# CXXXII
# CXXXIII
# CXXXIV
# CXXXV
# CXXXVI
# CXXXVII
# CXXXVIII
# CXXXIX
# ...

# %%
def convert_to_roman(num):     
    symbols = {1000:'M', 900:'CM', 500:'D', 400:'CD', 100:'C', 90:'XC',
               50:'L', 40:'XL', 10:'X', 9:'IX', 8:'VIII', 7:'VII', 6:'VI', 
               5:'V', 4:'IV', 3:'III', 2:'II', 1:'I'}
    r_num = str(num)[::-1]
    layers = (10**i * int(r_num[i]) for i in range(len(r_num)))
    numeral = []
    for i, p in enumerate(layers):
        if p in symbols.keys():
            numeral.append(symbols[p])
        elif int(str(p)[0]) < 4:
            numeral.append(symbols[10 ** (len(str(p)) -1)] * int(r_num[i]))
        else:
            numeral.append(symbols[10 ** (len(str(p)) -1) * 5]+ symbols[10 ** (len(str(p)) -1)] * (int(r_num[i]) - 5))
    numeral.reverse()
    return ''.join(numeral)

convert_to_roman(2250)
# Out:
# 'MMCCL'

# %%
switch = True
while switch:
    number = int(input('Please enter a number between 1 and 3999 _ '))
    if 0 < number < 4000:
        switch = False
symbols = [(1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), 
           (100, 'C'), (90, 'XC'), (50, 'L'), (40, 'XL'), 
           (10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')]    
roman_number = ''
for num, letter in symbols:
    roman_number += letter * (number//num)
    number %= num
    
    print(number, roman_number)
# Out:
# Please enter a number between 1 and 3999 _ 256
# 256
# 256
# 256
# 256
# 56 CC
# 56 CC
# 6 CCL
# 6 CCL
# 6 CCL
# 6 CCL
# 1 CCLV
# 1 CCLV
# 0 CCLVI

# %%
def convert_to_roman(num):
    d = [(1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), 
         (100, 'C'), (90, 'XC'), (50, 'L'), (40, 'XL'), 
         (10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')]
    
    res = ''
    for value, numeral in d:
        res += numeral * (num//value)
        num %= value
    return res
convert_to_roman(2000)
# Out:
# 'MM'

# %%
def convert_to_roman(num):
    symbols = [(1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), 
               (100, 'C'), (90, 'XC'), (50, 'L'), (40, 'XL'), 
               (10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')]    
    roman_number = ''
    for num, letter in symbols:
        roman_number += letter * (number//num)
        number %= num
    return roman_number
# Out:
# [(1, 'I'), (4, 'IV'), (5, 'V'), (9, 'IX'), (10, 'X'), (40, 'XL'), (50, 'L'), (90, 'XC'), (100, 'C'), (400, 'CD'), (500, 'D'), (900, 'CM'), (1000, 'M')]
